# %%
import pandas as pd

# %%
data = [{"Name":"Liza","Age":22},{"Name":"Ved","Age":23},{"Name":"Viggi","Age":24},{"Name":"Priyanshu","Age":23}]

# %%
df_1 = pd.DataFrame(data)

# %%
df_1.head()
# Out:
#         Name  Age
# 0       Liza   22
# 1        Ved   23
# 2      Viggi   24
# 3  Priyanshu   23

# %%
data2 = [{"Name":"X","Age":22},{"Name":"Y","Age":23},{"Name":"Z","Age":24},{"Name":"A","Age":23}]

# %%
df3 = pd.concat([df_1, df2], ignore_index=True)
df3
# Out:
#         Name  Age
# 0       Liza   22
# 1        Ved   23
# 2      Viggi   24
# 3  Priyanshu   23
# 4          X   22
# 5          Y   23
# 6          Z   24
# 7          A   23

# %%
df2 = pd.DataFrame(data2)

# %%
df2
# Out:
#   Name  Age
# 0    X   22
# 1    Y   23
# 2    Z   24
# 3    A   23

# %%
df4 = pd.DataFrame([{"Class":5, "Subject":"Maths"},{"Class":5, "Subject":"Science"},{"Class":5, "Subject":"Eng"}])

# %%
df4
# Out:
#    Class  Subject
# 0      5    Maths
# 1      5  Science
# 2      5      Eng

# %%
df5 = pd.concat([df3, df4], axis=0)

# %%
df5
# Out:
#         Name   Age  Class  Subject
# 0       Liza  22.0    NaN      NaN
# 1        Ved  23.0    NaN      NaN
# 2      Viggi  24.0    NaN      NaN
# 3  Priyanshu  23.0    NaN      NaN
# 4          X  22.0    NaN      NaN
# 5          Y  23.0    NaN      NaN
# 6          Z  24.0    NaN      NaN
# 7          A  23.0    NaN      NaN
# 0        NaN   NaN    5.0    Maths
# 1        NaN   NaN    5.0  Science
# 2        NaN   NaN    5.0      Eng

# %%
df_a = pd.DataFrame([{'Score':1, 'Age' : 22},{'Score':3, 'Age' : 53},{'Score':2, 'Age' : 40},{'Score':1, 'Age' : 18},{'Score':5, 'Age' : 65},{'Score':3, 'Age' : 46}])

# %%
df_a
# Out:
#    Score  Age
# 0      1   22
# 1      3   53
# 2      2   40
# 3      1   18
# 4      5   65
# 5      3   46

# %%
df_a['Score_Grade'] = df_a['Score'].map(lambda x: "A" if x == 1 else "B" if x == 2 else "C" if x == 3 else "D" if x == 4 else "E")

# %%
df_a
# Out:
#    Score  Age Score_Grade
# 0      1   22           A
# 1      3   53           C
# 2      2   40           B
# 3      1   18           A
# 4      5   65           E
# 5      3   46           C

# %%
df_a['Old_Young_Adult'] = df_a['Age'].map(lambda x : "Old" if x>55 else "Adult" if x>24 else "Young")
df_a
# Out:
#    Score  Age Score_Grade Old_Young_Adult
# 0      1   22           A           Young
# 1      3   53           C           Adult
# 2      2   40           B           Adult
# 3      1   18           A           Young
# 4      5   65           E             Old
# 5      3   46           C           Adult
