# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("L:\\Workspace\\Datasets\\ReviewsDatasets\\all_combined.csv")
df.shape
# Out:
# (200000, 4)

# %%
df.duplicated(subset=['content']).sum()
# Out:
# np.int64(70958)

# %%
df.drop_duplicates(subset=['content'], inplace=True)

# %%
df.duplicated(subset=['content']).sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# reviewId    0
# content     1
# score       0
# app         0
# dtype: int64

# %%
df['content'].isnull().sum()
# Out:
# np.int64(1)

# %%
df.dropna(subset=['content'], inplace=True)

# %%
df.isnull().sum()
# Out:
# reviewId    0
# content     0
# score       0
# app         0
# dtype: int64

# %%
df.shape
# Out:
# (129041, 4)

# %%
df.head()
# Out:
#                                reviewId  \
# 0  6aa90e7d-be9d-4615-9332-dfca8062c77b
# 1  fe84588e-aacf-448e-8e9a-b8d77ce01c59
# 2  8038ade0-929b-4447-b02d-344d146685fd
# 3  39b156a8-4f22-491c-b90a-a19eddbc38e7
# 4  048e8ffd-5b5c-447b-b9d0-4da6b6f73581
#
#                                              content  score       app
# 0                                            awesome      5  Facebook
# 1                                               good      5  Facebook
# 2  i would say it's great but meta just keeps sus...      2  Facebook
# 3  from 2012 my fb page in active mode ..Facebook...      5  Facebook
# 4                                  I think very good      1  Facebook

# %%
df = df['content']

# %%
df.shape
# Out:
# (129041,)

# %%
# Only content is required for topic modeling 
df.head()
# Out:
# 0                                              awesome
# 1                                                 good
# 2    i would say it's great but meta just keeps sus...
# 3    from 2012 my fb page in active mode ..Facebook...
# 4                                    I think very good
# Name: content, dtype: object

# %% [markdown]
# We will start with LDA -> Count vectorizer + LDA.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(max_df= 0.95, min_df=2, stop_words="english")

# %%
dtm = cv.fit_transform(df)

# %%
dtm.shape
# Out:
# (129041, 20032)

# %%
# Lets get LDA -

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
lda = LatentDirichletAllocation(n_components= 10, random_state= 42)

# %%
lda.fit(dtm)
# Out:
# LatentDirichletAllocation(random_state=42)

# %%
len(lda.components_)
# Out:
# 10

# %%
lda.components_.shape
# Out:
# (10, 20032)

# %% [markdown]
# ### Ok, so we have got 20032 words. And in lda we got probrability of these words to get into topics

# %% [markdown]
# #### Lets get for topic 1 - what all words have highest probrability of coming in topic 1

# %%
topic_one = lda.components_[0]

# %%
top_30_topic_one_words = topic_one.argsort()[-30:] 
top_30_topic_one_words
# This should give me 30 such words which have highest probrability -
# Out:
# array([ 6035, 10205, 10065, 17099, 11527,  6022,  3440,  9366,  3434,
#        12259, 17377,  4950,  5241, 16865,  8633, 15113,   808, 16848,
#        17306, 10818,  6218, 12913,  1438, 12251,   936, 15340,  1297,
#         3704, 11788, 14572])

# %% [markdown]
# Ok we have to get the word using indexes - we can do it with that get feature name

# %%
cv.get_feature_names_out()[6035]
# Out:
# 'feed'

# %%
for k in top_30_topic_one_words:
    print(cv.get_feature_names_out()[k])
# Out:
# feed
# microsoft
# memories
# videos
# page
# feature
# comments
# like
# comment
# posts
# way
# don
# edit
# users
# just
# stories
# ads
# used
# want
# news
# flipboard
# read
# articles
# post
# ai
# super
# app
# content
# people
# skype

# %% [markdown]
# Lets print for every topic first

# %%
for i in range(10):
    topic = lda.components_[i]
    top_30_words = topic.argsort()[-30:]
    print("Topic - ", i)
    print([cv.get_feature_names_out()[x] for x in top_30_words])
    print()
# Out:
# Topic -  0
# ['feed', 'microsoft', 'memories', 'videos', 'page', 'feature', 'comments', 'like', 'comment', 'posts', 'way', 'don', 'edit', 'users', 'just', 'stories', 'ads', 'used', 'want', 'news', 'flipboard', 'read', 'articles', 'post', 'ai', 'super', 'app', 'content', 'people', 'skype']
#
# Topic -  1
# ['google', 'using', 'watching', 'movie', 'let', 'just', 'live', 'tv', 'want', 'line', 'device', 'don', 'shows', 'password', 'sign', 'email', 'love', 'help', 'code', 'new', 'log', 'movies', 'old', 'login', 'tiktok', 'watch', 'number', 'account', 'netflix', 'phone']
#
# Topic -  2
# ['line', 'suspended', 'chat', 'log', 'whatsapp', 'use', 'phone', 'know', 'try', 'update', 'tried', 'got', 'just', 'reason', 'help', 'facebook', 'error', 'open', 'don', 'issue', 'send', 'support', 'viber', 'new', 'message', 'messages', 'fix', 'problem', 'app', 'account']
#
# Topic -  3
# ['levels', 'interesting', 'played', 'mind', 'surfers', 'wonderful', 'aap', 'enjoy', 'subway', 'pass', 'great', 'just', 'level', 'reliable', 'really', 'games', 'cool', 'perfect', 'happy', 'time', 'nice', 'like', 'playing', 'best', 'useful', 'excellent', 'play', 'fun', 'love', 'game']
#
# Topic -  4
# ['pay', 'bisa', 'payment', 'charged', 'ang', 'card', 'la', 'fb', 'ko', 'month', 'trial', 'ng', 'sa', 'plan', 'facebook', 'que', 'god', 'ok', 'fantastic', 'credit', 'di', 'lite', '10', 'na', 'cancel', 'free', 'wow', 'subscription', 'better', 'ads']
#
# Topic -  5
# ['times', 'working', 'pay', 'need', 'does', 'data', 'screen', 'want', 'storage', 'download', 'like', 'using', 'bad', 'years', 'used', 'open', 've', 'money', 'files', 'work', 'update', 'doesn', 'dropbox', 'phone', 'ads', 'don', 'use', 'just', 'time', 'app']
#
# Topic -  6
# ['whatsapp', 'thanks', 'think', 'helpful', 'snapchat', 'download', 'thank', 'people', 'bad', 'experience', 'communication', 'share', 'working', 'make', 'using', 'application', 'family', 'best', 'work', 'fast', 'like', 'friends', 'apps', 'really', 'love', 'easy', 'use', 'nice', 'app', 'good']
#
# Topic -  7
# ['phone', 'reels', 'calling', 'mobile', 'videos', 'camera', 'add', 'photo', 'service', 'thank', 'version', 'audio', 'picture', 'feature', 'voice', 'like', 'sound', 'friendly', 'clear', 'android', 'features', 'option', 'line', 'user', 'chat', 'calls', 'update', 'quality', 'amazing', 'video']
#
# Topic -  8
# ['pay', 'hate', 'make', 'playlist', 'recommend', 'listening', 'people', 'use', 'really', 'adds', 'best', 'better', 'experience', 'free', 'play', 'worst', 'want', 'listen', 'love', 'don', 'song', 'ads', 'just', 'songs', 'premium', 'spotify', 'music', 'like', 'great', 'app']
#
# Topic -  9
# ['like', 'nahi', 'informative', 'tiktok', 'nhi', 'aap', 'se', 'bahut', 'application', 'hi', 'far', 'great', 'ho', 'facebook', 'information', 'amazing', 'helpful', 'life', 'instagram', 'platform', 'thanks', 'media', 'social', 'world', 'love', 'awesome', 'hai', 'news', 'best', 'app']

# %%
lda_2 = LatentDirichletAllocation(n_components=6, random_state=42)

# %%
lda_2.fit(dtm)
# Out:
# LatentDirichletAllocation(n_components=6, random_state=42)

# %%
for i in range(len(lda_2.components_)):
    topic = lda_2.components_[i]
    top_30_words = topic.argsort()[-30:]
    print("Topic - ", i)
    print([cv.get_feature_names_out()[x] for x in top_30_words])
    print()
# Out:
# Topic -  0
# ['love', 'users', 'page', 'used', 'platform', 'information', 'videos', 'way', 'feature', 'option', 'stories', 'want', 'great', 'just', 'user', 'ads', 'post', 'read', 'flipboard', 'social', 'media', 'articles', 'like', 'super', 'ai', 'content', 'people', 'skype', 'news', 'app']
#
# Topic -  1
# ['want', 'just', 'device', 'movies', 'really', 'use', 'helpful', 'work', 'sign', 'service', 'don', 'password', 'code', 'email', 'new', 'line', 'help', 'old', 'watch', 'log', 'login', 'tiktok', 'love', 'app', 'number', 'netflix', 'phone', 'nice', 'account', 'good']
#
# Topic -  2
# ['messenger', 'reason', 'don', 'thank', 'help', 'just', 'support', 'line', 'like', 'viber', 'error', 'add', 'whatsapp', 'open', 'send', 'issue', 'new', 'message', 'facebook', 'friends', 'chat', 'messages', 'update', 'easy', 'fix', 'problem', 'use', 'best', 'account', 'app']
#
# Topic -  3
# ['fast', 'interesting', 'experience', 'aap', 'enjoy', 'video', 'games', 'happy', 'useful', 'perfect', 'cool', 'easy', 'app', 'time', 'quality', 'playing', 'nice', 'hai', 'awesome', 'really', 'excellent', 'amazing', 'great', 'play', 'like', 'fun', 'best', 'good', 'love', 'game']
#
# Topic -  4
# ['god', 'credit', '10', 'month', 'payment', 'plan', 'just', 'adds', 'thanks', 'playlist', 'na', 'like', 'pay', 'listening', 'want', 'play', 'wow', 'love', 'cancel', 'listen', 'subscription', 'song', 'free', 'great', 'better', 'songs', 'premium', 'ads', 'spotify', 'music']
#
# Topic -  5
# ['make', 'working', 'need', 'worst', 'money', 'works', 'open', 'update', 'download', 'really', 'want', 'doesn', 'years', 'dropbox', 've', 'files', 'used', 'work', 'bad', 'using', 'good', 'phone', 'ads', 'great', 'don', 'time', 'like', 'use', 'just', 'app']
